# %%
from dotenv import load_dotenv
from groq import Groq
import os
load_dotenv()

client = Groq(
    api_key=os.environ.get("GROQ_API")
)

# %% [markdown]
# - Transformação de formato -> mudança de estrutura
# - Transformação de tom -> ajuste de estilo
# - Transformação de perspectiva -> mudança de ponto de vista
# - Adaptaçao para público -> linguagem adequada ao leitor

# %% [markdown]
# ### Transformação de Formato

# %%
system_prompt = """

Você é um especialista em formatação de conteúdo.
Transforme textos entre diferentes estruturas garantindo:
1) clareza
2) preservação das informações originais
3) boa organização
"""

user_prompt = """

Transforme este parágrafo em uma receita passo a passo:
"para preparar um bom café gelado, você deve moer grãos de café fresco, preparar um café forte,
deixar esfriar, adicionar gelo em um copo alto e complementar com leite ou creme a gosto.
Finalize com um toque de açucar ou xarope de baunilha.

"""

response = client.chat.completions.create(

model = "openai/gpt-oss-120b",
messages=[
    {"role":"system", "content":system_prompt}
    , {"role":"user", "content":user_prompt}
],
    temperature=0.4,
    ##max_completion_tokens=400
    
)

print("=== Transformando o Formato ===")
print(response.choices[0].message.content)
# Out:
# === Transformando o Formato ===
# **Receita de Café Gelado**
#
# ---
#
# ### Ingredientes
# - 2 colheres (sopa) de café em grão fresco
# - 200 ml de água quente
# - Gelo (cerca de 1 a 2 xícaras, conforme o tamanho do copo)
# - Leite ou creme a gosto (aprox. 30‑50 ml)
# - Açúcar ou xarope de baunilha a gosto
#
# ---
#
# ### Modo de preparo – passo a passo
#
# 1. **Moer o café**
#    - Use um moedor de preferência para obter uma moagem média‑fina.
#    - Moa a quantidade necessária (cerca de 2 colheres de sopa).
#
# 2. **Preparar um café forte**
#    - Aqueça 200 ml de água até quase ferver (≈ 90‑95 °C).
#    - Passe a água pelos grãos moídos em uma cafeteira, prensa francesa ou filtro, usando o dobro da proporção normal de café para obter um café concentrado.
#
# 3. **Deixar esfriar**
#    - Transfira o café quente para um recipiente de vidro ou metal.
#    - Deixe em temperatura ambiente por 5‑10 min ou coloque na geladeira até ficar morno.
#
# 4. **Montar o copo**
#    - Encha um copo alto (300‑350 ml) até a metade com gelo.
#
# 5. **Adicionar o café gelado**
#    - Despeje o café já frio sobre o gelo, preenchendo quase todo o copo.
#
# 6. **Complementar com leite ou creme**
#    - Acrescente leite ou creme a seu gosto (geralmente 30‑50 ml).
#    - Misture suavemente com uma colher ou canudo.
#
# 7. **Adoçar**
#    - Adicione açúcar ou xarope de baunilha conforme a preferência.
#    - Mexa novamente até dissolver completamente.
#
# 8. **Servir**
#    - Sirva imediatamente, com canudo ou colher longa.
#    - Opcional: decore com uma pitada de canela ou cacau em pó.
#
# ---
#
# **Dica extra:**
# Se quiser um café ainda mais refrescante, prepare o café forte com antecedência e mantenha-o na geladeira. Assim, ao montar a bebida, o café já estará bem gelado e o gelo não diluirá tanto a bebida. Boa degustação!

# %% [markdown]
# ### Transformação em Tom

# %%
system_prompt = """

Você é um especialista em adaptação de estilo.
Transforme textos mudando oi tom sem perder o sentido.
"""

user_prompt = """

Transforme este texto jornalístico em um post leve para redes sociais:

"A cidade de Lisboa recebeu mais de 4 milhões de turistas em 2024,
consolidando-se como um dos destinos mais procurados da Europa.

"""

response = client.chat.completions.create(

model = "openai/gpt-oss-120b",
messages=[
    {"role":"system", "content":system_prompt}
    , {"role":"user", "content":user_prompt}
],
    temperature=0.7,
    ##max_completion_tokens=400
    
)

print("=== RESULTADO (Tom) ===")
print(response.choices[0].message.content)
# Out:
# === RESULTADO (Tom) ===
# 🌍✨ Lisboa bombando em 2024! Mais de **4 milhões** de turistas já passaram pela nossa capital, confirmando que a cidade está entre os destinos mais desejados da Europa. 🎒✈️ #Lisboa #Turismo #ViagemDosSonhos #EuropeExplore #VemPraLisboa
