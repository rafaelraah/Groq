# %% [markdown]
# ### COT = chain of thought

# %% [markdown]
# #### Cadeia de Pensamento
#
# Útil em situações:
# - Raciocínio estruturado e explícito
# - Explicação transparente do raciocínio
# - Clareza na tomada de decisão

# %%
from dotenv import load_dotenv
from groq import Groq
import os
load_dotenv()

client = Groq(
    api_key=os.environ.get("GROQ_API")
)

# %% [markdown]
# ### CoT para estratégia de Marketing

# %%
system_prompt = """

Você é um estrategista de marketing que sempre usa Chain of Thoughts (CoT).
Mostre o raciocínio dentro de <cot> e depois dê uma conclusão objetiva.

"""

user_prompt = """Uma empresa de moda quer lançar uma campannha para atrair a geração Z

Dados:
- Orçamento: 500 mil
- Principais canais: Instagram, tiktok, youtube
- Objetivo: aumentar vendas online em 30% em 6 meses
- Concorrência: 3 marcas fortes no mesmo segmento

Crie um plano de campanha explicando o raciocínio passo a passo.

"""

response = client.chat.completions.create(

model = "openai/gpt-oss-120b",
messages=[
    {"role":"system", "content":system_prompt}
    , {"role":"user", "content":user_prompt}
],
    temperature=0.4,
    ##max_completion_tokens=400
    
)

print("=== Plano de Marketing ===")
print(response.choices[0].message.content)
# Out:
# === Plano de Marketing ===
# <cot>
# 1. **Entender a Geração Z**
#    - Valores: autenticidade, diversidade, sustentabilidade, rapidez.
#    - Consumo de mídia: curtos vídeos (TikTok, Reels), conteúdo interativo, influenciadores micro‑nicho.
#    - Preferem comprar diretamente nas plataformas (social commerce) e valorizam experiências de compra gamificadas.
#
# 2. **Analisar o cenário competitivo**
#    - Três concorrentes fortes já investem pesado em influenciadores e coleções cápsula.
#    - Oportunidade: diferenciação por storytelling de marca (ex.: origem dos tecidos, processos sustentáveis) e por formatos de conteúdo (UGC, challenges, AR filters).
#
# 3. **Definir metas SMART**
#    - Aumentar vendas online 30% em 6 meses → crescimento médio mensal de 4,5%.
#    - KPIs: ROAS, CAC, taxa de conversão, engajamento (likes, shares, comentários), número de UGC criados.
#
# 4. **Alocação do orçamento (R$ 500 mil)**
#    - Produção de conteúdo criativo (vídeos curtos, fotos, AR filters): 30% → R$150 mil.
#    - Influenciadores (macro + micro): 35% → R$175 mil.
#    - Paid media (ads Instagram, TikTok, YouTube Shorts): 25% → R$125 mil.
#    - Ferramentas e tecnologia (analytics, plataforma de social commerce, giveaways): 5% → R$25 mil.
#    - Reserva para otimização (testes A/B, boost de posts de melhor performance): 5% → R$25 mil.
#
# 5. **Estratégia de conteúdo por canal**
#    - **Instagram**: Reels 15‑30 s mostrando “look do dia” com música trending + carrossel de bastidores (sustentabilidade). Uso de Shopping Tags.
#    - **TikTok**: Challenges de 15 s (“#MeuEstiloXYZ”) incentivando UGC; duetos com influenciadores; filtros AR que permitem “experimentar” roupas virtualmente.
#    - **YouTube**: Shorts (30 s) e vídeos de 3‑5 min (lookbooks, “behind the scenes”, entrevistas com designers). Integração de links de compra na descrição.
#
# 6. **Calendário de execução (6 meses)**
#    - **Mês 1**: Pesquisa de tendências, briefing criativo, seleção de influenciadores, produção de assets iniciais. Lançamento teaser + pré‑cadastro de lista de e‑mail (lead magnet: desconto exclusivo).
#    - **Mês 2‑3**: Lançamento da campanha principal (challenge TikTok + Reels). Início de ads pagos com segmentação por interesse e look‑alike de clientes atuais. Promoções semanais (ex.: “Compre 2, leve 3”).
#    - **Mês 4**: Introdução de coleção cápsula limitada (co‑criada com micro‑influenciador). Uso de AR filter para “provar” a peça.
#    - **Mês 5**: Intensificar UGC – concurso de melhor vídeo com prêmio de viagem fashion. Retargeting de quem interagiu mas não converteu.
#    - **Mês 6**: “Flash sale” final, análise de resultados, otimização de criativos vencedores para escalonamento.
#
# 7. **Métricas de controle e otimização**
#    - Dashboard diário: impressões, CPC, CTR, custo por aquisição, taxa de conversão por canal.
#    - Testes A/B: criativo vs. criativo, CTA (“Swipe up” vs. “Link na bio”), formatos de anúncio (in‑feed vs. story).
#    - Ajuste de verba: realocar até 20% da mídia para os criativos com ROAS > 4.
#
# 8. **Riscos e mitigação**
#    - **Baixo engajamento**: ter criativos prontos para pivotar (ex.: mudar música, usar humor).
#    - **Saturação de influenciadores**: diversificar entre macro (alcance) e micro (engajamento).
#    - **Problemas de estoque**: integrar sistema de inventory em tempo real ao social commerce.
#
# 9. **Retorno esperado**
#    - Com ROAS médio 5, CAC ≤ R$30, a campanha deve gerar aproximadamente R$2,5 milhões em vendas (30% de aumento sobre baseline de R$1,9 mi), cobrindo o investimento e entregando lucro adicional.
#
# </cot>
#
# **Conclusão objetiva:**
# Alocar R$500 mil em produção de conteúdo criativo, influenciadores e mídia paga, focando em vídeos curtos e challenges no TikTok e Instagram Reels, complementados por Shorts no YouTube. Executar um calendário de 6 meses com lançamentos de teasers, challenge, coleção cápsula e flash sale, monitorando KPIs diários e otimizando a verba para criativos com ROAS ≥ 5. Essa estratégia deve elevar as vendas online em 30% nos próximos 6 meses, superando a concorrência ao combinar storytelling autêntico, UGC e tecnologia de AR.

# %% [markdown]
# ### CoT para saúde

# %%
system_prompt = """

Você é um médico que sempre usa Chain of Thoughts (CoT) para racíocinio clínico.
Mostre o raciocínio dentro de <cot> e depois dê uma recomendação objetiva.

"""

user_prompt = """Paciente: 45 anos, sedentário, fumante, apresenta dores no peito durante esforço físico.

Exames iniciais: colesterol alto, pressão arterial elevada.

Qual deve ser a recomendação inicial para o paciente?

"""

response = client.chat.completions.create(

model = "openai/gpt-oss-120b",
messages=[
    {"role":"system", "content":system_prompt}
    , {"role":"user", "content":user_prompt}
],
    temperature=0.4,
    ##max_completion_tokens=400
    
)

print("=== Análise Clínica ===")
print(response.choices[0].message.content)
# Out:
# === Análise Clínica ===
# <cot>
# 1. **Identificação dos fatores de risco**
#    - Idade: 45 anos (risco moderado).
#    - Sedentarismo: aumenta risco de doença arterial coronariana (DAC).
#    - Tabagismo: fator de risco forte para DAC e hipertensão.
#    - Colesterol alto: provável dislipidemia aterogênica.
#    - Pressão arterial elevada: hipertensão arterial sistêmica, outro fator de risco cardiovascular.
#
# 2. **Sintoma apresentado**
#    - Dor torácica ao esforço físico → sugestiva de angina típica ou angina de esforço, indicando possível isquemia miocárdica.
#
# 3. **Objetivo imediato**
#    - Reduzir risco cardiovascular global.
#    - Aliviar sintomas e prevenir eventos agudos (infarto do miocárdio).
#    - Avaliar a presença de doença coronariana significativa.
#
# 4. **Estratégias de manejo inicial**
#    a) **Modificação do estilo de vida**
#       - Cessação do tabagismo (intervenção farmacológica + apoio psicológico).
#       - Introdução de atividade física gradual (ex.: caminhada 30 min/dia, 5 dias/semana) após avaliação cardiológica.
#       - Dieta balanceada (DASH ou mediterrânea) para redução de LDL e pressão arterial.
#       - Controle de peso, se houver sobrepeso/obesidade.
#
#    b) **Tratamento farmacológico**
#       - **Hipertensão:** iniciar inibidor da enzima conversora de angiotensina (IECA) ou bloqueador dos receptores de angiotensina (BRA) para atingir < 130/80 mmHg.
#       - **Dislipidemia:** iniciar estatina de alta intensidade (ex.: atorvastatina 40‑80 mg ou rosuvastatina 20‑40 mg) para reduzir LDL < 70 mg/dL.
#       - **Profilaxia antiagregante:** considerar aspirina baixa dose (81‑100 mg) se risco cardiovascular ≥ 10 % (avaliar risco usando SCORE ou ASCVD).
#
#    c) **Investigação diagnóstica**
#       - Realizar teste ergométrico ou teste de esforço com imagem (ecocardiografia ou cintilografia) para confirmar isquemia e estratificar risco.
#       - Caso teste positivo ou alto risco, encaminhar ao cardiologista para possível coronariografia.
#
# 5. **Prioridade**
#    - A intervenção mais impactante a curto prazo é a cessação do tabagismo, seguida de controle da pressão arterial e início de estatina.
#    - Simultaneamente, agendar teste de esforço para avaliação da dor torácica.
# </cot>
#
# **Recomendação objetiva:**
# 1. Iniciar programa de cessação do tabagismo imediatamente (nicotina em substituição + apoio comportamental).
# 2. Prescrever um IECA (ex.: enalapril 5 mg 1×/dia) para controlar a pressão arterial, ajustando a dose conforme necessidade.
# 3. Iniciar estatina de alta intensidade (atorvastatina 40 mg 1×/dia).
# 4. Avaliar necessidade de aspirina baixa dose (81 mg) com base no cálculo de risco cardiovascular.
# 5. Marcar teste de esforço (ergométrico ou com imagem) nas próximas 2‑3 semanas.
# 6. Orientar dieta DASH/mediterrânea e iniciar atividade física leve (caminhada 20‑30 min, 5 dias/semana) após liberação do teste de esforço.
#
# Essas medidas combinadas visam reduzir o risco de evento cardiovascular agudo, melhorar os sintomas e estabelecer a base para o manejo a longo prazo.
