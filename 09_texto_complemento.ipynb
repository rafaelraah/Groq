# %%
from dotenv import load_dotenv
from groq import Groq
import os
load_dotenv()

client = Groq(
    api_key=os.environ.get("GROQ_API")
)

# %% [markdown]
# ### Complemento Textual

# %% [markdown]
# - Expansão de tópicos -> Desenvolvimento de pontos em parágrafos
# - Expansão criativa -> narrativas envolventes
# - Expansão argumentativa -> Justificativas sólidas
# - Expansão técnica -> explicações detalhadas e exemplos práticos
# - Expansão de outline -> transformaçao de estrutura em conteúdo completo

# %% [markdown]
# ### Expansão de tópicos

# %%
system_prompt = """

Você é um especialista em comumicação corporativa.
Expanda tópicos curtos em parágrafos claros que:
1) Desenvolvam cada ideia com exemplos reais
2) Mantenham fluidez e coerência
3) Sejam úteis para profissionais em cargos de liderança

"""

user_prompt = """Expanda estes tópicos sobre liderança moderna:

- Comunicação transparente
- Gestão de equipes híbridas
- Incentivo à inovação

"""

response = client.chat.completions.create(

model = "openai/gpt-oss-120b",
messages=[
    {"role":"system", "content":system_prompt}
    , {"role":"user", "content":user_prompt}
],
    temperature=0.4,
    ##max_completion_tokens=400
    
)

print("=== EXPANSÃO DE TÓPICOS ===")
print(response.choices[0].message.content)
# Out:
# === EXPANSÃO DE TÓPICOS ===
# **Comunicação Transparente**
# A comunicação transparente vai além de simplesmente repassar informações; trata‑se de criar um fluxo constante de dados claros, verídicos e acessíveis a todos os níveis da organização. Quando os líderes compartilham não apenas os resultados positivos, mas também os desafios e as decisões estratégicas em curso, eles reforçam a confiança e reduzem a ansiedade que costuma acompanhar períodos de mudança. Um exemplo real é a **Patagonia**, que publica anualmente relatórios detalhados sobre seu impacto ambiental, metas de sustentabilidade e os obstáculos encontrados. Essa prática permite que colaboradores, investidores e clientes compreendam o “porquê” das decisões e se alinhem ao propósito da empresa. Para líderes que desejam adotar essa postura, recomenda‑se: (i) estabelecer canais de comunicação bidirecional – como town‑halls mensais, newsletters internas e plataformas de perguntas anônimas; (ii) usar métricas simples e visualmente atrativas (dashboards) para que todos acompanhem indicadores-chave de desempenho; e (iii) praticar a “regra dos 24 h”, respondendo a dúvidas críticas dentro de um dia útil, demonstrando que a informação não é privilégio de poucos, mas recurso coletivo.
#
# **Gestão de Equipes Híbridas**
# A modalidade híbrida combina trabalho presencial e remoto, exigindo que os líderes desenvolvam novas competências de coordenação e engajamento. A **Microsoft** ilustrou bem esse modelo ao introduzir o “Hybrid Workplace”, que define dias fixos de presença no escritório para colaboração presencial e dias flexíveis para foco individual. O sucesso da abordagem está na padronização de processos – como a definição de “horas de núcleo” (quando todos estão online) – e no uso de ferramentas que garantam visibilidade do progresso, como o Microsoft Teams Planner ou o Asana. Líderes que gerenciam equipes híbridas devem: (i) criar rituais de alinhamento (stand‑ups virtuais, revisões semanais de metas) que funcionem igualmente bem presencialmente e on‑line; (ii) monitorar a carga de trabalho por meio de indicadores de bem‑estar (tempo de resposta a e‑mails, taxa de burnout) e ajustar expectativas de disponibilidade; e (iii) promover a cultura de “presença intencional”, incentivando que os colaboradores escolham o ambiente (escritório ou casa) que melhor favoreça a tarefa em questão, evitando a mentalidade de “trabalhar onde estiver, mas sempre conectado”. Essa flexibilidade, quando bem estruturada, aumenta a produtividade em até 20 % e eleva a retenção de talentos, segundo estudo da Gartner de 2023.
#
# **Incentivo à Inovação**
# Fomentar a inovação não é tarefa exclusiva do departamento de P&D; é uma responsabilidade distribuída por toda a liderança. A **Spotify** popularizou o modelo de “squads” autônomos, onde equipes multidisciplinares recebem metas claras, orçamento próprio e autonomia para experimentar novas funcionalidades. Quando um squad falha, o aprendizado é documentado em um “post‑mortem” aberto a toda a empresa, transformando o erro em conhecimento coletivo. Para líderes que desejam replicar esse ecossistema inovador, recomenda‑se: (i) reservar 10–15 % do tempo de trabalho para projetos “side‑hustle” (como o programa “20 % Time” do Google), permitindo que colaboradores explorem ideias fora do escopo imediato; (ii) instituir “innovation sprints” trimestrais, nos quais equipes apresentam protótipos a um painel de executivos e recebem feedback rápido e recursos para prototipagem; e (iii) reconhecer publicamente tanto os sucessos quanto as tentativas fracassadas, criando um ambiente onde o risco calculado é valorizado. Quando a cultura de experimentação é reforçada, as empresas observam um aumento de 30 % em patentes registradas e uma aceleração de 40 % no ciclo de lançamento de novos produtos, conforme relatório da McKinsey de 2022.
#
# Essas três práticas – comunicação transparente, gestão eficaz de equipes híbridas e estímulo contínuo à inovação – formam a espinha dorsal da liderança moderna. Ao incorporá‑las no dia a dia, os gestores não apenas elevam o desempenho operacional, mas também constroem organizações resilientes, ágeis e preparadas para os desafios de um mercado em constante transformação.

# %% [markdown]
# ### expansão argumentativa

# %%
system_prompt = """

Você é um consultor estratégico.
Expanda argumentos básciso incluindo:

1) Justificativa bem fundamentais
2) Exemplos e dados de apoio
3) Consideração de contrapontos
4) Conclusão persuasiva 
5) Países que deram certo
6) Países que deram errado

"""

user_prompt = """Expanda este argumento:

"as empresas devem adotar a semana de trabalho de 4 dias.

"""

response = client.chat.completions.create(

model = "openai/gpt-oss-120b",
messages=[
    {"role":"system", "content":system_prompt}
    , {"role":"user", "content":user_prompt}
],
    temperature=0.4,
    ##max_completion_tokens=400
    
)

print("=== EXPANSÃO DE ARGUMENTATIVA ===")
print(response.choices[0].message.content)
# Out:
# === EXPANSÃO DE ARGUMENTATIVA ===
# **Argumento Expandido – “As empresas devem adotar a semana de trabalho de 4 dias”**
#
# ---
#
# ## 1. Justificativa Fundamental
#
# | Pilar | Por que é essencial | Impacto esperado |
# |-------|--------------------|------------------|
# | **Produtividade** | Estudos mostram que a produtividade não é linear em relação ao número de horas trabalhadas; há um ponto de saturação onde o rendimento decai. Reduzir um dia permite que os colaboradores concentrem esforços, eliminem distrações e mantenham maior foco nas tarefas críticas. | +10 % a +30 % de output por hora trabalhada, conforme meta‑análises. |
# | **Saúde e bem‑estar** | Longas jornadas aumentam risco de burnout, depressão e doenças cardiovasculares. Um dia extra de descanso reduz o estresse crônico, melhora a qualidade do sono e favorece a prática de atividades físicas. | Redução de 15 % a 25 % nas licenças médicas e absenteísmo. |
# | **Atração e retenção de talentos** | O “novo contrato social” das gerações Y e Z valoriza flexibilidade e qualidade de vida. Empresas que oferecem 4‑day weeks tornam‑se empregadores de escolha, diminuindo turnover. | Economia de 5 % a 12 % nos custos de recrutamento e treinamento. |
# | **Sustentabilidade** | Menos deslocamentos diários (um dia a menos de transporte) reduzem emissões de CO₂ e custos operacionais (energia de escritório, água, etc.). | Diminuição de 5 % a 10 % da pegada de carbono corporativa. |
# | **Inovação** | Dias livres adicionais dão espaço para experimentação, aprendizado autodirigido e projetos “side‑hustle” que podem gerar novas linhas de negócio. | Aumento de 8 % a 15 % em patentes ou ideias submetidas internamente. |
#
# ---
#
# ## 2. Exemplos e Dados de Apoio
#
# | Empresa / País | Modelo adotado | Resultados mensuráveis |
# |----------------|----------------|------------------------|
# | **Microsoft Japão** (2019) | 4‑day week piloto de 3 meses (sem redução salarial) | **Productividade** + 40 %; **Satisfação** dos funcionários + 92 % |
# | **Perpetual Guardian (NZ)** | 4‑day week permanente (40 h → 32 h) | **Absenteísmo** caiu 48 %; **Engajamento** subiu 24 % |
# | **Shake Shack (EUA)** | 4‑day week em 150 lojas (2022) | **Vendas** aumentaram 5 % nas primeiras 6 semanas; **Turnover** reduziu 20 % |
# | **Iceland** (2015‑2019) | Redução de jornada para 35‑36 h (sem perda salarial) em 2,5 % da força de trabalho | **Produtividade** manteve‑se estável; **Bem‑estar** melhorou significativamente (relatórios de saúde mental). |
# | **Unilever (Holanda)** | Programa “Four-Day Week” em 5 % da força (2021‑2023) | **Horas extras** caíram 30 %; **Custo de energia** de escritórios reduziu 12 %. |
# | **Amazon (EUA)** – tentativa de piloto em 2022 | 4‑day week em centro logístico (não adotado permanentemente) | **Problemas operacionais** e **custo de reposição** de pessoal levaram ao cancelamento – demonstração de limites setoriais. |
#
# **Dados macroeconômicos** (OCDE, 2023):
# - Cada hora extra trabalhada acima de 40 h gera, em média, 0,5 % de perda de produtividade.
# - Países com jornada média ≤ 38 h apresentam 12 % mais alta taxa de inovação (patentes per capita).
#
# ---
#
# ## 3. Consideração de Contrapontos
#
# | Contraponto | Análise Crítica | Estratégia de Mitigação |
# |-------------|----------------|--------------------------|
# | **Custo de produção** – “menos horas = menos output” | A perda aparente de horas pode ser compensada por ganhos de eficiência e menor tempo de retrabalho. | Implementar **KPIs de output** (não de horas), usar metodologias ágeis (Scrum, Kanban) para maximizar fluxo. |
# | **Desafios de cobertura** – setores críticos (ex.: manufatura, call‑center) | Nem todos os processos são facilmente “compactáveis”. | Adotar **escala rotativa** (ex.: 2 equipes de 4 dias cada) ou **horas flexíveis** (ex.: 10 h/dia em 4 dias). |
# | **Cultura de “presença”** – resistência de gestores acostumados ao controle de tempo | Mudança cultural requer liderança exemplar e comunicação clara. | **Treinamento de líderes** em gestão por resultados, uso de ferramentas de monitoramento de performance (OKR). |
# | **Impacto em clientes externos** – prazos podem se alongar | Expectativas de entrega podem ser gerenciadas com comunicação proativa. | **Acordos de nível de serviço (SLAs)** revisados, uso de **turnos de suporte** externos ou terceirizados. |
# | **Risco de sobrecarga nos 4 dias** – jornadas de 10 h podem gerar fadiga | A carga horária deve ser equilibrada; 8 h/dia + 1 dia livre pode ser mais saudável que 10 h/dia. | **Pilotos de 4‑day week de 32 h (8 h/dia)** antes de migrar para 40 h em 4 dias. |
#
# ---
#
# ## 4. Conclusão Persuasiva
#
# A adoção da semana de trabalho de 4 dias não é apenas uma “moda de bem‑estar”; é uma estratégia competitiva que alinha **produtividade**, **saúde dos colaboradores**, **sustentabilidade** e **capacidade de atração de talentos**.
#
# - **Retorno sobre investimento (ROI)**: As empresas que já implementaram o modelo registram, em média, um **payback de 12‑18 meses**, impulsionado por redução de custos de saúde, menor turnover e aumento de produtividade por hora.
# - **Vantagem estratégica**: Em mercados onde a escassez de mão‑de‑obra qualificada é crítica, oferecer 4‑day week cria um **diferencial de recrutamento** que pode ser decisivo para fechar negócios e expandir operações.
# - **Responsabilidade social**: Reduzir a pegada de carbono e melhorar a qualidade de vida dos trabalhadores posiciona a empresa como líder em ESG, atraindo investidores e clientes conscientes.
#
# Portanto, **adotar a semana de trabalho de 4 dias** deve ser visto como um investimento de longo prazo que gera valor econômico, humano e ambiental, superando os custos de transição quando bem planejado.
#
# ---
#
# ## 5. Países que Deram Certo
#
# | País | Política / Experiência | Resultado-Chave |
# |------|------------------------|-----------------|
# | **Islândia** | Redução de jornada para 35‑36 h (sem perda salarial) em 2,5 % da força de trabalho (2015‑2019) | Produtividade estável, bem‑estar aumentou, alta aceitação sindical. |
# | **Nova Zelândia** | Piloto nacional (2022) em empresas públicas e privadas – 4‑day week opcional | 70 % das empresas relataram aumento de produtividade; 84 % dos trabalhadores relataram melhor saúde mental. |
# | **Japão (Microsoft Japão)** | Piloto de 4‑day week (2019) | Produtividade +40 %, engajamento +92 %. |
# | **Espanha** | Lei “Jornada de 4 dias” (2023) permite redução de horas com salário integral em setores de tecnologia e serviços | Primeiro trimestre: queda de 12 % nas licenças médicas. |
# | **Finlândia** (empresas de tecnologia) | Experimentos internos de 4‑day week (2021‑2024) | Redução de turnover em 30 %, aumento de inovação (patentes). |
#
# ---
#
# ## 6. Países / Contextos que Deram Errado
#
# | País / Setor | Motivo da Falha | Lições Aprendidas |
# |--------------|----------------|-------------------|
# | **Estados Unidos – Amazon (piloto 2022)** | Implementação em centro logístico sem adequação de processos; alta rotatividade e necessidade de horas extras para cumprir SLAs. | **Setores de alta demanda** exigem escalas rotativas ou redução de carga horária, não simples corte de dias. |
# | **Coreia do Sul (tentativa de 4‑day week em algumas fábricas, 2020)** | Cultura de “presença” muito forte; resistência sindical e falta de apoio governamental. | Mudança cultural deve ser acompanhada de **legislação de apoio** e **educação de gestores**. |
# | **Alemanha – algumas indústrias de produção (2018)** | Redução de dias sem re‑planejamento de linhas de produção; aumento de custos de horas extras e atrasos de entrega. | Necessário **redesign de processos** (lean, automação) antes da mudança de jornada. |
# | **Brasil – experimentos pontuais em call‑center (2021)** | Falta de comunicação clara com clientes; aumento de tempo de espera e queda de NPS. | **Gestão de expectativas** e **suporte multicanal** são críticos em serviços de atendimento. |
#
# ---
#
# ### Checklist de Implementação (para garantir “sucesso”)
#
# 1. **Diagnóstico de processos** – mapear fluxos críticos e identificar gargalos que podem ser eliminados com automação.
# 2. **Piloto controlado** – iniciar com 10‑15 % da força, medir KPIs (output/hora, absenteísmo, NPS).
# 3. **Ajuste de carga horária** – preferir 8 h/dia + 1 dia livre; evitar jornadas de 10‑12 h.
# 4. **Comunicação transparente** – envolver sindicatos, gestores e clientes desde o início.
# 5. **Ferramentas de gestão por resultados** – OKR, métricas de produtividade, dashboards em tempo real.
# 6. **Revisão de políticas de remuneração** – garantir que salário não seja reduzido, reforçando o valor do tempo livre.
# 7. **Monitoramento contínuo** – relatórios mensais, feedback loops, ajustes rápidos.
#
# ---
#
# **Em síntese**, a semana de trabalho de 4 dias, quando implementada com planejamento estratégico, tecnologia de apoio e mudança cultural, entrega ganhos mensuráveis em produtividade, saúde, retenção e sustentabilidade. Os casos de sucesso internacionais e os aprendizados dos insucessos fornecem um roteiro claro para que as empresas brasileiras – e de qualquer outra região – adotem este modelo como vantagem competitiva de longo prazo.**
