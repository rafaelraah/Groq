# %% [markdown]
# ### Técnicas Few Shot Prompting

# %% [markdown]
# - zero shot: sem exemplos, apenas instruções
# - one shot: um exemplo para instruir o modelo
# - few shot: múltiplos exemplos para melhor compreensão

# %%
from dotenv import load_dotenv
from groq import Groq
import os
load_dotenv()

client = Groq(
    api_key=os.environ.get("GROQ_API")
)

# %% [markdown]
# ### Zero Shot Prompting

# %%
system_prompt = """

Você é um chef renomado.

Receba o nome de um ingrediente e sugira um prato sofisticado 
onde ele seja protagonista.

"""

user_prompt = """Abacate"""

response = client.chat.completions.create(

model = "openai/gpt-oss-120b",
messages=[
    {"role":"system", "content":system_prompt}
    , {"role":"user", "content":user_prompt}
],
    temperature=0.5,
    ##max_completion_tokens=400
    
)

print("=== Zero Shot ===")
print(response.choices[0].message.content)
# Out:
# === Zero Shot ===
# **Prato‑estrela:** *Tartar de Abacate com Ceviche de Camarão Rosa, Gel de Limão Siciliano e Crocante de Semente de Chia*
#
# ---
#
# ### Conceito
# Um jogo de texturas e contrastes que eleva o abacate a protagonista de uma composição refinada: a cremosidade aveludada do tartar, a acidez vibrante do ceviche, o frescor cítrico do gel e o toque crocante das sementes torradas. Cada elemento conversa harmoniosamente, criando uma experiência sensorial digna de um restaurante com estrela Michelin.
#
# ---
#
# ### Ingredientes (para 2 porções)
#
# | Ingrediente | Quantidade |
# |-------------|------------|
# | **Abacate Hass maduro** | 2 unidades médias (polpa somente) |
# | **Camarão rosa** | 200 g, limpo e sem casca |
# | **Suco de limão siciliano** | 60 ml |
# | **Raspas de limão siciliano** | 1 colher de chá |
# | **Cebola roxa** | 30 g, finamente picada |
# | **Pimentão vermelho** | 20 g, cubos pequenos |
# | **Coentro fresco** | 1 colher de sopa, folhas picadas |
# | **Molho de soja envelhecido** | 10 ml |
# | **Óleo de gergelim torrado** | 5 ml |
# | **Pimenta dedo‑de‑moça** | 1 unidade, sem sementes e picada finamente |
# | **Sal marinho** | a gosto |
# | **Pimenta branca moída** | a gosto |
# | **Gel de limão siciliano** (ver receita abaixo) | 30 ml |
# | **Sementes de chia** | 2 colheres de sopa |
# | **Azeite de oliva extra virgem** | 10 ml |
# | **Flor de sal** | para finalizar |
# | **Microvegetais (broto de rabanete, folhas de erva‑doce)** | para decoração |
#
# ---
#
# ### Preparação
#
# #### 1. Gel de Limão Siciliano
# 1. Misture 100 ml de suco de limão siciliano, 50 ml de água filtrada e 30 g de açúcar.
# 2. Leve ao fogo baixo até o açúcar dissolver completamente.
# 3. Retire do fogo, adicione 2 g de agar‑agar (pré‑disperso em 10 ml de água fria) e ferva por 1 minuto.
# 4. Despeje em uma forma rasa (cerca de 1 cm de profundidade) e deixe solidificar em geladeira (≈30 min). Corte em cubos de 1 cm antes de montar o prato.
#
# #### 2. Crocante de Chia
# 1. Em uma frigideira antiaderente, aqueça 10 ml de azeite em fogo médio.
# 2. Adicione as sementes de chia e mexa constantemente até que adquiram cor dourada e liberem um aroma tostado (≈2 min). Reserve em papel absorvente.
#
# #### 3. Ceviche de Camarão
# 1. Corte o camarão em cubos de 1 cm.
# 2. Marinar com suco de limão siciliano, molho de soja, óleo de gergelim, pimenta dedo‑de‑moça, sal e pimenta branca por 8‑10 min (o camarão “cozinha” no ácido).
# 3. Incorpore a cebola roxa, pimentão vermelho e coentro. Reserve em temperatura ambiente.
#
# #### 4. Tartar de Abacate
# 1. Corte o abacate em cubos de 1 cm e tempere levemente com sal, pimenta branca e um fio de azeite.
# 2. Em um aro de metal (cerca de 6 cm de diâmetro), coloque uma camada de abacate, pressione levemente com as costas de uma colher para firmar, mas sem amassar.
# 3. Sobre o abacate, disponha o ceviche de camarão, nivelando a superfície.
#
# #### 5. Montagem
# 1. No centro do prato, posicione o aro contendo o tartar de abacate + ceviche.
# 2. Remova o aro cuidadosamente, mantendo a forma.
# 3. Distribua ao redor 3‑4 cubos de gel de limão siciliano.
# 4. Salpique o crocante de chia por cima e ao redor para dar textura.
# 5. Decore com microvegetais e finalize com um leve fio de azeite e uma pitada de flor de sal.
#
# ---
#
# ### Dicas do Chef
#
# - **Escolha do abacate:** Prefira o Hass, que tem textura mais cremosa e sabor mais encorpado. Verifique a maturação ao apertar levemente: cede, mas não amassa.
# - **Limão siciliano:** O aroma floral e a acidez mais suave realçam o frescor do prato sem sobrepor o sabor delicado do camarão.
# - **Agar‑agar:** Use exatamente a dose indicada; excesso deixará o gel duro, enquanto menos resultará em consistência líquida.
# - **Temperatura:** Sirva o prato ligeiramente frio (cerca de 10 °C). Isso mantém a firmeza do ceviche e realça a cremosidade do abacate.
# - **Apresentação:** O aro de metal garante linhas perfeitas; se preferir, use um anel de silicone ou um molde de cerâmica.
#
# ---
#
# ### Harmonização sugerida
#
# - **Vinho:** Um **Alvarinho** (Portugal) ou um **Sauvignon Blanc** de clima fresco, com acidez viva que ecoa o limão siciliano.
# - **Coquetel:** *Gin Fizz* com infusão de pepino e um toque de água tônica, servindo como contraponto refrescante.
#
# ---
#
# **Resultado:** Um prato que celebra o abacate como protagonista, combinando sua textura aveludada com a vivacidade do mar, a acidez cítrica e o crocante inesperado da chia. Ideal para um menu degustação de alta gastronomia. Bon appétit!

# %% [markdown]
# ### One Shot Prompting

# %%
system_prompt = """

Você é um chef renomado.

Receba o nome de um ingrediente e sugira um prato sofisticado 
onde ele seja protagonista.

Exemplo:
Ingrediente: Salmão
Sugestão -> Tartar de salmão fresco com molho cítrico e torradas de brioche

"""

user_prompt = """Cogumelos"""

response = client.chat.completions.create(

model = "openai/gpt-oss-120b",
messages=[
    {"role":"system", "content":system_prompt}
    , {"role":"user", "content":user_prompt}
],
    temperature=0.5,
    ##max_completion_tokens=400
    
)

print("=== One Shot ===")
print(response.choices[0].message.content)
# Out:
# === One Shot ===
# **Sugestão:** Ravioli artesanal recheado com mistura de cogumelos silvestres (porcini, shiitake e chanterelle) ao molho de manteiga de sálvia, finalizado com lascas de trufa negra e um toque de parmesão envelhecido.

# %% [markdown]
# ### Few Shot Prompting

# %%
system_prompt = """

Você é um chef renomado.

Receba o nome de um ingrediente e sugira um prato sofisticado 
onde ele seja protagonista.

<exemplos>
Ingrediente: Tomate
Sugestão -> Carpaccio de tomate com azeite trufado e manjericão fresco

Ingrediente: chocolate
Sugestão -> soufflé de chocolate meio amargo com calda de frutas vermelhas

Ingrediente: batata
Sugestão -> nhoque artesanal de batata ao molho de manteiga e sálvia
</exemplos>
"""

user_prompt = """Camarão"""

response = client.chat.completions.create(

model = "openai/gpt-oss-120b",
messages=[
    {"role":"system", "content":system_prompt}
    , {"role":"user", "content":user_prompt}
],
    temperature=0.5,
    ##max_completion_tokens=400
    
)

print("=== Few Shot ===")
print(response.choices[0].message.content)
# Out:
# === Few Shot ===
# **Ingrediente:** Camarão
# **Sugestão ->** Risoto de camarão ao champagne com espuma de limão siciliano, finalizado com lascas de pistache torrado e micro-ervas frescas.
