# %%
from dotenv import load_dotenv
from groq import Groq
import os
load_dotenv()

client = Groq(
    api_key=os.environ.get("GROQ_API")
)

# %% [markdown]
# ### Análise Textual - Cores e Ambientes

# %%
system_prompt = """

Você é um especialista em análise visual. Dada uma descrição de imagem, identifique:
1. Paleta de cores dominante
2. Clima ou atmosfera sugerida
3. Elementos de cenário
"""

user_prompt = """

Descrição:

"Uma praia ao entardecer, com o céu em tons de laranja e roxo, ondas suaves 
batendo na areia clara e algumas gaivotas voando no horizonte

"""

response = client.chat.completions.create(

model = "openai/gpt-oss-120b",
messages=[
    {"role":"system", "content":system_prompt}
    , {"role":"user", "content":user_prompt}
],
    temperature=0.4,
    ##max_completion_tokens=400
    
)

print("=== Análise Textual - Cores e Ambientes ===")
print(response.choices[0].message.content)
# Out:
# === Análise Textual - Cores e Ambientes ===
# **1. Paleta de cores dominante**
# - **Laranja quente** (pôr‑do‑sol no céu)
# - **Roxo profundo** (matizes crepusculares)
# - **Bege/areia clara** (areia da praia)
# - **Azul‑acinzentado** (ondas suaves)
# - **Branco/cinza claro** (gaivotas e detalhes de espuma)
#
# **2. Clima ou atmosfera sugerida**
# - **Entardecer tranquilo e romântico** – luz dourada do sol poente misturada a tons frios de roxo cria um clima sereno e levemente melancólico.
# - **Brisa marítima suave** – as ondas calmas e as gaivotas ao longe reforçam a sensação de paz e relaxamento.
#
# **3. Elementos de cenário**
# - **Céu**: gradiente de laranja a roxo, possivelmente com nuvens finas.
# - **Mar**: ondas suaves que chegam à margem, com espuma branca.
# - **Areia**: superfície clara, possivelmente levemente úmida.
# - **Gaivotas**: silhuetas voando próximo ao horizonte, sugerindo movimento.
# - **Horizonte**: linha onde o mar encontra o céu, enfatizando a amplitude da paisagem.

# %% [markdown]
# ### Análise Textual - Objetos e Elementos

# %%
system_prompt = """

VocÇe é um analista de iamgens em texto. Identifique:
1. Objetos principais
2. Relações entre eles
3. Elementos secundários

"""

user_prompt = """

Descrição:

Um escritório moderno com uma mesa de madeira, um laptop aberto,
uma xícara de café fumegante e uma estante cheia de livros ao fundo.

"""

response = client.chat.completions.create(

model = "openai/gpt-oss-120b",
messages=[
    {"role":"system", "content":system_prompt}
    , {"role":"user", "content":user_prompt}
],
    temperature=0.7,
    ##max_completion_tokens=400
    
)

print("=== RESULTADO (Objetos e Elementos) ===")
print(response.choices[0].message.content)
# Out:
# === RESULTADO (Objetos e Elementos) ===
# **1. Objetos principais**
# - Mesa de madeira
# - Laptop aberto
# - Xícara de café fumegante
# - Estante cheia de livros (localizada ao fundo)
#
# **2. Relações entre eles**
# - O **laptop** está **sobre** a **mesa de madeira**.
# - A **xícara de café** está **sobre** a **mesa de madeira**, ao lado (ou próximo) do laptop.
# - A **estante** está **posicionada ao fundo** da cena, formando o pano‑de‑fundo do escritório.
# - Todos os objetos compõem o **cenário de um escritório moderno**.
#
# **3. Elementos secundários (contexto / detalhes implícitos)**
# - Ambiente de **escritório moderno** (design clean, iluminação possivelmente natural ou de LED).
# - Possível **cadeira** em frente à mesa (não descrita, mas típica).
# - **Parede** ou **janela** ao fundo que delimita o espaço.
# - **Iluminação** que realça o laptop e a xícara de café (luz de teto ou luz de bancada).
# - **Detalhes de decoração** sutis (p. ex., um vaso pequeno, um quadro na parede) que reforçam o estilo moderno, ainda que não estejam explicitamente mencionados.

# %% [markdown]
# ### Análise Simbólica

# %%
system_prompt = """

Você é um especialista em semiótica visual. Interprete:
1. Significados simbólicos dos elementos
2. Possíveis metáforas
3. Impacto emocional no observador

"""

user_prompt = """

Descrição:

Uma vela acesa em meio a uma sala escura,
iluminando apenas um diário aberto e uma fotografia antiga.

"""

response = client.chat.completions.create(

model = "openai/gpt-oss-120b",
messages=[
    {"role":"system", "content":system_prompt}
    , {"role":"user", "content":user_prompt}
],
    temperature=0.7,
    ##max_completion_tokens=400
    
)

print("=== RESULTADO (analise simbólica) ===")
print(response.choices[0].message.content)
# Out:
# === RESULTADO (analise simbólica) ===
# ## 1. Significados simbólicos dos elementos
#
# | Elemento | Significado tradicional / cultural | Nuances que emergem no conjunto |
# |----------|-----------------------------------|---------------------------------|
# | **Vela acesa** | • Luz frágil, transitoriedade (a chama pode se apagar a qualquer momento). <br>• Presença de espírito, memória ou ritual (velas são usadas em cerimônias religiosas, funerárias, de lembrança). <br>• Esperança e resistência contra a escuridão. | • A vela é a única fonte de luz, sugerindo que a “verdade” ou a “recordação” depende de algo delicado e humano. <br>• O ato de acender a vela pode indicar um gesto deliberado de “trazer à tona” algo que estava oculto. |
# | **Sala escura** | • Ignorância, desconhecido, medo do que está oculto. <br>• Espaço interior, introspecção (a escuridão externa reflete o interior da mente). | • O contraste entre a penumbra e a chama reforça a ideia de que o passado (representado pelo diário e pela foto) está “enterrado” e só pode ser visto quando alguém se dispõe a iluminar. |
# | **Diário aberto** | • Testemunho pessoal, relato íntimo, confissão. <br>• Temporalidade: o que foi escrito permanece, mas ainda está “em processo” (aberto, não fechado). | • O fato de estar aberto indica que a história está sendo lida, revisitada, ou que o narrador está pronto a “escrever” algo novo a partir da lembrança. |
# | **Fotografia antiga** | • Memória congelada no tempo, nostalgia, permanência visual. <br>• Relicário de identidade (mostra rostos, lugares, momentos que já não existem). | • A foto, ao ser iluminada pela vela, ganha vida momentânea, como se a luz da lembrança fosse capaz de “reviver” o passado. |
# | **Iluminação restrita (apenas o diário e a foto)** | • Foco seletivo: o que vale a pena ver, o que se quer lembrar. <br>• Exclusão do resto da sala simboliza que tudo o mais está “apagado” ou irrelevante para a narrativa presente. | • Cria um pequeno “santuário” de memória dentro de um vasto vazio, sugerindo que o passado pode ser sagrado ou doloroso. |
#
# ---
#
# ## 2. Possíveis metáforas
#
# 1. **“A chama da memória”** – A vela representa a energia frágil que mantém viva a lembrança. Quando a luz toca o diário e a foto, a memória “se revela”.
# 2. **“Escrita na penumbra”** – O ato de escrever (ou ler) em um ambiente escuro pode simbolizar a busca interior por sentido em meio à confusão ou ao sofrimento.
# 3. **“O passado como luz que corta a escuridão”** – O diário e a foto são “pontos de luz” que interrompem a escuridão do tempo presente, sugerindo que o passado pode orientar ou iluminar decisões atuais.
# 4. **“Ritual de reconciliação”** – Acender a vela em uma sala escura pode ser visto como um ritual de reconciliação com o que foi perdido (a pessoa da foto, os eventos anotados).
# 5. **“A fragilidade da história”** – A chama pode se apagar a qualquer instante; assim, a história contida no diário e na foto é vulnerável, dependente de quem a mantém acesa (leitores, descendentes).
# 6. **“Silêncio revelado”** – A ausência de outros objetos ou sons (a sala está vazia) faz com que o silêncio seja “ouvido” como um espaço para a introspecção; a luz quebra esse silêncio ao revelar o conteúdo.
#
# ---
#
# ## 3. Impacto emocional no observador
#
# | Aspecto visual | Efeito psicológico / emocional | Por quê? |
# |----------------|--------------------------------|----------|
# | **Contraste luz/escuro** | Sensação de vulnerabilidade + curiosidade. O olho humano é atraído instantaneamente para a fonte de luz, gerando foco e, ao mesmo tempo, a percepção de que tudo ao redor está oculto e possivelmente ameaçador. | A biologia da visão prioriza áreas iluminadas; a escuridão ativa o medo do desconhecido. |
# | **Vela tremeluzente** | Calmante, porém tenso. O movimento sutil da chama cria um ritmo quase meditativo, mas a sua instabilidade lembra que a situação pode mudar a qualquer momento. | A chama é associada a rituais de luto e a momentos de contemplação, evocando simultaneamente serenidade e ansiedade. |
# | **Diário aberto** | Empatia e intimidade. Ler fragmentos de um diário faz o observador sentir que está “espiando” pensamentos privados, gerando conexão emocional. | O ato de abrir um diário sugere vulnerabilidade; o leitor sente-se convidado a partilhar segredos. |
# | **Fotografia antiga** | Nostalgia e melancolia. Imagens em preto‑e‑branco ou sépia tendem a evocar um “tempo perdido”, despertando saudade ou pesar. | A foto fixa um momento que não pode ser revivido, reforçando a ideia de perda irrecuperável. |
# | **Ambiente fechado e silencioso** | Sensação de claustrofobia ou intimidade profunda, dependendo da predisposição do observador. | O isolamento visual amplifica a atenção nos poucos objetos iluminados, intensificando a carga emocional desses objetos. |
# | **Foco seletivo (apenas o diário e a foto)** | Sentimento de sacralidade. Quando apenas dois objetos recebem luz, eles adquirem um tom quase litúrgico, como ícones em um altar. | O cérebro interpreta a iluminação direcionada como sinal de importância, conferindo a esses itens um status de “sagrado”. |
#
# ### Resumo do efeito global
#
# - **Mistura de reverência e melancolia**: O observador sente respeito pelo ato de preservar a memória (a vela como ritual) ao mesmo tempo que lamenta a passagem do tempo (foto antiga, diário já escrito).
# - **Urgência silenciosa**: A fragilidade da chama cria uma tensão latente – “e se a luz se apagar?” – que pode gerar um desejo implícito de proteger ou registrar a memória antes que desapareça.
# - **Intimidade forçada**: O espaço reduzido e a ausência de distrações forçam o espectador a confrontar a história pessoal (diário) e a identidade coletiva (foto) de forma direta, gerando empatia profunda ou desconforto, dependendo da relação pessoal com lembranças dolorosas.
#
# ---
#
# ### Como usar essa leitura
#
# - **Narrativa visual**: Se for um quadro, filme ou fotografia, enfatize a textura da cera, o brilho trêmulo da chama e a nitidez da foto para maximizar a carga simbólica.
# - **Comunicação de marca**: Uma empresa que queira transmitir “memória que perdura” pode adotar essa composição, usando a vela como metáfora de cuidado e a foto como símbolo de legado.
# - **Terapia ou memória familiar**: O cenário pode ser usado como ponto de partida para sessões de reminiscência, convidando as pessoas a “acender a vela” e revisitar diários ou fotos antigas.
#
# Em suma, a cena funciona como um pequeno altar da memória: a luz frágil da vela ilumina, revela e protege o que foi escrito e fotografado, ao mesmo tempo que nos lembra da transitoriedade da própria lembrança. O observador, ao entrar nesse espaço, sente-se simultaneamente guardião e testemunha de um passado que ainda pulsa, porém vulnerável.

# %% [markdown]
# ### Análise Comparativa

# %%
descricao_a = "Um campo de trigo dourado sob um céu azul claro, com uma árvore solitária no horizonte"

descricao_b = "Uma metrópole movimentada à noite, cheia de arranha-céus iluminados e ruas lotadas."

comparison_prompt = f"""

Compare estas duas descrições de imagens:
1. Diferenças de cores e atmosferas
2. Elementos principais
3. Estilos possíveis
4. Emoções transmitidas

DESCRIÇÃO A: {descricao_a}

DESCRIÇÃO B: {descricao_b}

"""

response = client.chat.completions.create(

model = "openai/gpt-oss-120b",
messages=[
     {"role":"user", "content":comparison_prompt}
],
    temperature=0.7,
    ##max_completion_tokens=400
    
)

print("=== RESULTADO (ANÁLISE COMPARATIVA) ===")
print(response.choices[0].message.content)
# Out:
# === RESULTADO (ANÁLISE COMPARATIVA) ===
# **Comparação entre a Descrição A e a Descrição B**
#
# | Aspecto | **Descrição A – Campo de trigo** | **Descrição B – Metrópole noturna** |
# |---|---|---|
# | **1. Diferenças de cores e atmosferas** | • **Cores predominantes:** tons quentes de dourado e amarelo do trigo, azul celeste do céu, verde‑escuro da árvore. <br>• **Atmosfera:** calma, serena, quase atemporal; sensação de amplitude e tranquilidade. <br>• **Luz:** luz natural difusa do dia, sombras suaves. | • **Cores predominantes:** contrastes fortes entre preto/azul‑escuro do céu noturno e luzes neon (branco, amarelo, rosa, azul elétrico) dos edifícios. <br>• **Atmosfera:** vibrante, agitada, urbana; sensação de movimento constante. <br>• **Luz:** iluminação artificial, reflexos nas fachadas de vidro, brilhos de néon que criam sombras marcadas. |
# | **2. Elementos principais** | • **Campo de trigo:** textura ondulada, mar de ouro. <br>• **Árvore solitária:** ponto focal que quebra a planaridade do campo. <br>• **Horizonte aberto:** sugere espaço infinito. | • **Arranha‑céus iluminados:** silhuetas verticais que dominam a composição. <br>• **Ruas lotadas:** fluxo de veículos e pedestres, linhas de fuga que conduzem o olhar. <br>• **Luzes neon e letreiros:** detalhes que dão ritmo visual. |
# | **3. Estilos possíveis** | • **Pintura impressionista** – pinceladas soltas para capturar a luz dourada. <br>• **Fotografia de paisagem** – uso de filtro de calor para realçar o dourado. <br>• **Arte minimalista** – foco na árvore como único elemento de contraste. <br>• **Ilustração de fantasia pastoral** – realçando a sensação de conto de fadas. | • **Cyber‑punk / Futurismo** – ênfase nas luzes neon e na densidade urbana. <br>• **Realismo urbano** – detalhe minucioso das fachadas e da multidão. <br>• **Noir cinematográfico** – contrastes de luz e sombra, clima de mistério. <br>• **Grafite/Street art** – estilo mais gráfico, linhas fortes e cores saturadas. |
# | **4. Emoções transmitidas** | • **Paz e contemplação:** o campo aberto convida à respiração profunda e ao relaxamento. <br>• **Solidão serena:** a árvore isolada pode evocar melancolia suave ou introspecção. <br>• **Nostalgia rural:** lembrança de verões tranquilos e da ligação com a natureza. | • **Excitação e energia:** o movimento incessante das ruas gera adrenalina visual. <br>• **Ansiedade urbana:** a densidade e as luzes piscantes podem sugerir sobrecarga sensorial. <br>• **Admiração tecnológica:** fascínio pelos arranha‑céus e pela arquitetura futurista. <br>• **Isolamento na multidão:** apesar da aglomeração, há uma sensação de anonimato. |
#
# ### Resumo comparativo
#
# - **Cores & atmosfera:** A A traz calor, suavidade e espaço aberto; a B mergulha em contrastes frios‑quentes, luz artificial e densidade visual.
# - **Elementos chave:** O campo e a árvore são símbolos de natureza e simplicidade; a metrópole apresenta arquitetura vertical, iluminação neon e fluxo humano.
# - **Estilos artísticos:** Enquanto a A combina bem com abordagens impressionistas ou minimalistas, a B se presta a estilos cyber‑punk, noir ou realismo urbano.
# - **Emoções:** A A evoca tranquilidade, nostalgia e introspecção; a B desperta energia, fascínio tecnológico e, simultaneamente, a possível sensação de alienação urbana.
#
# Essas diferenças demonstram como duas descrições simples podem gerar universos visuais e sensoriais diametralmente opostos, oferecendo ao artista ou ao espectador caminhos criativos muito distintos.
