# %%
from dotenv import load_dotenv
from groq import Groq
import os
load_dotenv()

client = Groq(
    api_key=os.environ.get("GROQ_API")
)

# %% [markdown]
# ### Compreendendo os Roles
# - User: Mensagem do usuário
# - Assistant: Resposta do modelo
# - System: Instruções de comportamento para o modelo

# %%
chat_completion = client.chat.completions.create(
    messages=[{
            "role":"user",
            "content":"Me explique de forma reduzida o que são as LLMs",
        }
    ],
    model="groq/compound",
)
print(chat_completion.choices[0].message.content)
# Out:
# As LLMs (Large Language Models) são modelos de inteligência artificial treinados com enormes volumes de texto para aprender padrões da linguagem. Elas utilizam arquiteturas de redes neurais (geralmente Transformers) e, após o treinamento, conseguem gerar texto, responder perguntas, resumir conteúdos e executar outras tarefas linguísticas, tudo de forma autônoma e contextual. Em resumo, são “cérebro” de IA especializado em entender e produzir linguagem natural.
