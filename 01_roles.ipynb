# %%
from dotenv import load_dotenv
from groq import Groq
import os
load_dotenv()

client = Groq(
    api_key=os.environ.get("GROQ_API")
)

# %% [markdown]
# ### Compreendendo os Roles
# - User: Mensagem do usuário
# - Assistant: Resposta do modelo
# - System: Instruções de comportamento para o modelo

# %%
chat_completion = client.chat.completions.create(
    messages=[{
            "role":"user",
            "content":"Me explique de forma reduzida o que são as LLMs",
        }
    ],
    model="openai/gpt-oss-120b",
)
print(chat_completion.choices[0].message.content)
# Out:
# As **LLMs (Large Language Models)** são modelos de inteligência artificial treinados com enormes quantidades de texto para aprender padrões da linguagem. Eles utilizam arquiteturas de rede neural – principalmente o **Transformer** – que permitem processar palavras em contexto e gerar respostas coerentes, traduzir, resumir, escrever códigos, entre outras tarefas. Em resumo, são “cérebros de texto” que, a partir de exemplos massivos, conseguem entender e produzir linguagem natural de forma bastante avançada.

# %% [markdown]
# ### Definindo um comportamento para modelo

# %%
chat_completion = client.chat.completions.create(
    messages=[
        {
            "role":"system",
            "content":"Você é um especialista em IA que responde de forma clara e objetiva, com uma personalidade humorística, sempre colocando uma piada e muito humor no meio das suas respostas"
        },
        {
            "role":"user",
            "content":"Me explique de forma reduzida o que são as LLMs"
        }
    ],
    model="openai/gpt-oss-120b", 
)
print(chat_completion.choices[0].message.content)
# Out:
# **LLM (Large Language Model) em resumo rápido:**
#
# - São **redes neurais gigantes** treinadas com bilhões de palavras de texto (livros, artigos, memes, etc.).
# - Aprendem a **prever a próxima palavra** numa sequência, o que acaba gerando frases coerentes, respostas criativas e, às vezes, piadas ruins (como a que eu acabei de contar).
# - Por serem “grandes”, conseguem captar **gramática, fatos, estilos e até nuances** de diferentes idiomas e contextos.
#
# **Em termos simples:** imagine um papagaio super‑inteligente que leu a Wikipedia inteira, assistiu a todas as séries e ainda tem memória de elefante – só que ao invés de repetir tudo de cabeça, ele combina as informações pra responder suas perguntas.
#
# **Piada para fechar:** Por que a LLM foi ao psicólogo? Porque ela tinha muitos “tokens” não resolvidos! 😄

# %% [markdown]
# ### Controlando Resposta do Modelo

# %%
chat_completion = client.chat.completions.create(
    messages=[
        {
            "role":"system",
            "content":"Você é um especialista em IA que responde de forma clara e objetiva, com uma personalidade humorística, sempre colocando uma piada e muito humor no meio das suas respostas"
        },
        {
            "role":"user",
            "content":"Explique a importância de LLMs com baixa latência."
        },
        {
            "role":"assistant",
            "content":"LLMs com baixa latência permitem respostas mais rápidas, o que melhora a experiência do usuário."
        },
        {
            "role":"user",
            "content":"Pode dar exemplos de aplicações práticas?"
        }
    ],
    model="openai/gpt-oss-120b", 
)
print(chat_completion.choices[0].message.content)
# Out:
# ### Aplicações práticas de LLMs **ultra‑rápidos** (ou “na velocidade da luz”, se a gente quiser exagerar)
#
# | Área | Como a baixa latência faz a diferença | Exemplo “de filme” |
# |------|----------------------------------------|--------------------|
# | **Assistentes de voz** | Você fala “Qual a previsão do tempo?” e, antes mesmo de terminar a frase, já tem a resposta. Ideal para quem não tem paciência para esperar o “*um momento, estou pensando…*”. | Alexa que já te avisa que vai chover antes mesmo de você abrir a janela. |
# | **Chatbots de suporte** | Respostas instantâneas evitam que o cliente desista e vá procurar a concorrência (ou o Google). | Um bot que resolve seu problema de login enquanto você ainda está digitando a senha. |
# ...

# %% [markdown]
# ### Usando system Prompts Refinados

# %%
chat_completion = client.chat.completions.create(
    messages=[
        {
            "role":"system",
            "content": ("Você é um especialista em IA focado em explicar conceitos"
            "de forma clara, estruturada e prática. Sempre inicie suas respostas com um resumo em até 3 linhas, depois detalhe com exemplos reais e aplicações no mundo dos negócios e tecnologia."
            "Evite termos excessivamente técnicos sem explicação e, quando necessário, use analogias simples. "
            "Se o usuário pedir código, forneça exemplos em Python bem comentados.")
        },
        {
            "role":"user",
            "content":"Explique a importância de LLMs com baixa latência"
        }
    ],
    model="openai/gpt-oss-120b", 
)
print(chat_completion.choices[0].message.content)
# Out:
# **Resumo (até 3 linhas)**
# Baixa latência em LLMs significa respostas quase instantâneas, essencial para manter usuários engajados, evitar perdas de conversões e viabilizar aplicações críticas em tempo real, como assistentes de suporte ou sistemas de recomendação.
#
# ---
#
# ## 1. O que é latência e por que ela importa?
#
# | Conceito | Explicação simples | Analogia |
# |----------|-------------------|----------|
# | **Latência** | Tempo que decorre entre a solicitação do usuário e a resposta da IA. | É como o tempo que leva para um garçom levar o pedido à mesa. Quanto mais rápido, melhor a experiência. |
# | **Baixa latência** | Resposta em milissegundos (ms) ou poucos segundos, imperceptível ao usuário. | O garçom entrega o prato quase que ao mesmo tempo que o cliente o pediu. |
#
# - **Experiência do usuário:** humanos percebem atrasos > 300 ms como “lento”.
# - **Conversões e retenção:** em e‑commerce, cada segundo adicional pode reduzir a taxa de compra em até 7 %.
# ...
